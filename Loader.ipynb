# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Inline plots for ease of visualisation
# %matplotlib inline

# %%
df = pd.read_csv('../Orb/BoggerCycle_LD118.csv') #csv read
df.drop(df.columns[[0, 1]], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#   TippleName DrawPoint        StartDateTime          EndDateTime  Tonnage  \
# 0      DP103    112E05  2016-11-11 01:22:40  2016-11-11 01:25:48    16.95
# 1      DP103    112E05  2016-11-11 01:25:48  2016-11-11 01:28:29    16.30
# 2      DP103    112E05  2016-11-11 01:28:29  2016-11-11 01:35:55    14.00
# 3      DP103    112E05  2016-11-11 01:35:55  2016-11-11 01:39:55     9.15
# 4      DP103    112E05  2016-11-11 01:39:55  2016-11-11 01:46:09    13.65
# 5      DP103    112E05  2016-11-11 01:46:09  2016-11-11 01:48:13    13.45
# 6      DP103    112E05  2016-11-11 01:48:13  2016-11-11 01:50:24    17.40
# 7      DP103    112E05  2016-11-11 01:50:24  2016-11-11 01:52:08    17.45
# 8      DP103    112E05  2016-11-11 01:52:08  2016-11-11 01:54:18    18.45
# 9      DP103    112E05  2016-11-11 01:54:18  2016-11-11 01:56:32    19.50
#
#    StartLoadedDateTime  AuGrade  EmptyMetres  LoadedMetres  \
# 0  2016-11-11 01:22:40      NaN          NaN           NaN
# 1  2016-11-11 01:27:40      NaN          NaN           NaN
# 2  2016-11-11 01:34:46      NaN          NaN           NaN
# 3  2016-11-11 01:39:03      NaN          NaN           NaN
# 4  2016-11-11 01:45:23      NaN          NaN           NaN
# 5  2016-11-11 01:47:29      NaN          NaN           NaN
# 6  2016-11-11 01:49:39      NaN          NaN           NaN
# 7  2016-11-11 01:51:23      NaN          NaN           NaN
# 8  2016-11-11 01:53:10      NaN          NaN           NaN
# 9  2016-11-11 01:55:46      NaN          NaN           NaN
#
#                                             Operator  OrderID DataSource  \
# 0  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 1  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 2  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 3  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 4  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 5  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 6  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 7  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 8  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
# 9  8697ed3c178553472fcdd09939e91bd61190211e6bb8ee...      NaN        MPM
#
#   TonnesType _CreatedInOrbBy      _CreatedInOrbAt _LastUpdatedInOrbBy  \
# 0    Ordered             Orb  2016-11-11 01:26:01                 Orb
# 1    Ordered             Orb  2016-11-11 01:29:01                 Orb
# 2    Ordered             Orb  2016-11-11 01:36:07                 Orb
# 3    Ordered             Orb  2016-11-11 01:40:02                 Orb
# 4    Ordered             Orb  2016-11-11 01:46:31                 Orb
# 5    Ordered             Orb  2016-11-11 01:48:35                 Orb
# 6    Ordered             Orb  2016-11-11 01:50:31                 Orb
# 7    Ordered             Orb  2016-11-11 01:52:31                 Orb
# 8    Ordered             Orb  2016-11-11 01:54:31                 Orb
# 9    Ordered             Orb  2016-11-11 01:57:01                 Orb
#
#    _LastUpdatedInOrbAt  _UpdatedInOneViewAt
# 0  2016-11-11 01:26:09  2016-11-11 01:26:40
# 1  2016-11-11 01:29:03  2016-11-11 01:29:40
# 2  2016-11-11 01:36:10  2016-11-11 01:36:40
# 3  2016-11-11 01:40:14  2016-11-11 01:40:41
# 4  2016-11-11 01:46:40  2016-11-11 01:47:41
# 5  2016-11-11 01:48:44  2016-11-11 01:49:41
# 6  2016-11-11 01:50:41  2016-11-11 01:51:41
# 7  2016-11-11 01:52:33  2016-11-11 01:52:41
# 8  2016-11-11 01:54:33  2016-11-11 01:54:41
# 9  2016-11-11 01:57:12  2016-11-11 01:57:42

# %%
import glob
from datetime import datetime
df_mach = pd.DataFrame()
for name in glob.glob('../November2016/2016.11.1?/RCM00001/*_Complete_Log/LHDMachineData*'):
    dfx = pd.read_csv(name)
    dfx.drop(dfx.columns[[3, 4, 5, 36]], axis=1, inplace=True)
    dfx['OriginationTimeStamp'] = dfx['OriginationTime'].apply(lambda x:datetime.utcfromtimestamp(x))
    df_mach = df_mach.append(dfx)

# %%
df_mtech = pd.DataFrame()
for name in glob.glob('../November2016/2016.11.1?/RCM00001/*_Complete_Log/LHDMinetecRangeData*'):
    dfx = pd.read_csv(name)
    dfx.drop(dfx.columns[[3, 4]], axis=1, inplace=True)
    dfx['OriginationTimeStamp'] = dfx['OriginationTime'].apply(lambda x:datetime.utcfromtimestamp(x))
    df_mtech = df_mtech.append(dfx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a761a0051cf6> in <module>()
#       2     dfx = pd.read_csv(name)
#       3     dfx.drop(dfx.columns[[3, 4]], axis=1, inplace=True)
# ----> 4     dfx['OriginationTimeStamp'] = dfx['OriginationTime'].apply(lambda x:datetime.utcfromtimestamp(x))
#       5     df_mtech = df_mtech.append(dfx)
#
# C:\Users\Rob\Anaconda2\lib\site-packages\pandas\core\series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2292             else:
#    2293                 values = self.asobject
# -> 2294                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2295
#    2296         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:66124)()
#
# <ipython-input-6-a761a0051cf6> in <lambda>(x)
#       2     dfx = pd.read_csv(name)
#       3     dfx.drop(dfx.columns[[3, 4]], axis=1, inplace=True)
# ----> 4     dfx['OriginationTimeStamp'] = dfx['OriginationTime'].apply(lambda x:datetime.utcfromtimestamp(x))
#       5     df_mtech = df_mtech.append(dfx)
#
# NameError: global name 'datetime' is not defined

# %%
df_imu = pd.DataFrame()
for name in glob.glob('../November2016/2016.11.1?/RCM00001/*_Complete_Log/LHDIMUData*'):
    dfx = pd.read_csv(name)
    dfx.drop(dfx.columns[[3, 4,5,25]], axis=1, inplace=True)
    dfx['OriginationTimeStamp'] = dfx['OriginationTime'].apply(lambda x:datetime.utcfromtimestamp(x))
    df_imu = df_imu.append(dfx)

# %%
df_mach.head(10)
# Out:
#    OriginationTime  TransmissionTime  txSequenceNumber  Throttle Position (%)  \
# 0     1.162881e+09      1.162881e+09             16688                   99.6
# 1     1.162881e+09      1.162881e+09             16689                   99.6
# 2     1.162881e+09      1.162881e+09             16690                   58.4
# 3     1.162881e+09      1.162881e+09             16691                   40.4
# 4     1.162881e+09      1.162881e+09             16692                   28.0
# 5     1.162881e+09      1.162881e+09             16693                   56.0
# 6     1.162881e+09      1.162881e+09             16694                   80.0
# 7     1.162881e+09      1.162881e+09             16695                   67.6
# 8     1.162881e+09      1.162881e+09             16696                   96.8
# 9     1.162881e+09      1.162881e+09             16697                   98.0
#
#    Engine Speed (rpm)  Desired Engine Speed (rpm)  Boost Pressure (kPa)  \
# 0              1874.0                      2120.0                 119.0
# 1              1968.5                      2120.0                 123.0
# 2              1931.5                      1560.0                  93.0
# 3              1494.0                      1261.0                  44.5
# 4              1159.5                      1030.0                  25.5
# 5              1080.5                      1604.0                  17.0
# 6              1623.5                      2043.5                  27.0
# 7              1773.5                      1768.5                  42.5
# 8              1659.0                      2120.0                  69.5
# 9              1920.0                      2120.0                 108.0
#
#    Engine Load Factor (%)  Fuel Consumption Rate (l/h)  Ground Speed (mph)  \
# 0                     100                        25.90                 4.5
# 1                     100                        24.60                 5.0
# 2                      77                         0.00                 5.0
# 3                       0                         0.00                 2.0
# 4                       0                         0.00                 0.0
# 5                      41                        43.10                 0.0
# 6                      70                        28.15                 0.0
# 7                      51                        15.30                 0.5
# 8                      81                        29.20                 2.0
# 9                     100                        25.30                 3.0
#
#              ...              Reverse Steering Solenoid Status  \
# 0            ...                                   Err-Unknown
# 1            ...                                   Err-Unknown
# 2            ...                                   Err-Unknown
# 3            ...                                   Err-Unknown
# 4            ...                                   Err-Unknown
# 5            ...                                   Err-Unknown
# 6            ...                                   Err-Unknown
# 7            ...                                   Err-Unknown
# 8            ...                                   Err-Unknown
# 9            ...                                   Err-Unknown
#
#    Park Brake Status Service Brake Status Auto Retard Mode Status  \
# 0                Off             Released                     Off
# 1                Off             Released                     Off
# 2                Off             Released                     Off
# 3                Off             Released                     Off
# 4                Off            Depressed                     Off
# 5                Off            Depressed                     Off
# 6                Off            Depressed                     Off
# 7                Off             Released                     Off
# 8                Off             Released                     Off
# 9                Off             Released                     Off
#
#   Acceleration Pedal Status Front Service Brake Oil Pressure (kPa)  \
# 0                 Depressed                                      0
# 1                 Depressed                                      4
# 2                 Depressed                                    383
# 3                  Released                                   2725
# 4                  Released                                   2421
# 5                  Released                                   1579
# 6                 Depressed                                    205
# 7                 Depressed                                    188
# 8                 Depressed                                    106
# 9                 Depressed                                    103
#
#   Rear Service Brake Oil Pressure (kPa) Hydraulic Oil Temperature (degC)  \
# 0                                     0                               81
# 1                                     5                               81
# 2                                   408                               81
# 3                                  2764                               81
# 4                                  2606                               81
# 5                                  1757                               81
# 6                                   236                               81
# 7                                   346                               81
# 8                                   127                               81
# 9                                   122                               81
#
#   Fuel Gauge (%)       OriginationTimeStamp
# 0             80 2006-11-07 06:36:23.716911
# 1             80 2006-11-07 06:36:24.377059
# 2             80 2006-11-07 06:36:24.996929
# 3             80 2006-11-07 06:36:25.617042
# 4             83 2006-11-07 06:36:26.237147
# 5             87 2006-11-07 06:36:26.897090
# 6             87 2006-11-07 06:36:27.517201
# 7             87 2006-11-07 06:36:28.177292
# 8             87 2006-11-07 06:36:28.837191
# 9             87 2006-11-07 06:36:29.457610
#
# [10 rows x 34 columns]

# %%
df2.head(10)

# %%
fig, ax = plt.subplots(figsize=(18, 6))
df2.boxplot(column ='Engine Speed (rpm)')

# %%
df2.plot.scatter('OriginationTime',"Throttle Position (%)")

# %%
df2.plot.scatter('OriginationTime',"Throttle Position (%)")

# %%
df2.shape
